# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

geo_data = pd.read_csv("data_from_wijkbuurtkaart.csv") 
geo_data['buurtcode'] = geo_data['buurtcode'].astype(str).str.replace('BU0014', 'BU00')
geo_data.head()
# Out:
#   buurtcode         buurtnaam  wijkcode gemeentecode gemeentenaam  \
# 0  BU000000  Binnenstad-Noord  WK001400       GM0014    Groningen
# 1  BU001406        De Wierden  WK001414       GM0014    Groningen
# 2  BU000103     Rivierenbuurt  WK001401       GM0014    Groningen
# 3  BU001003    Zernike Campus  WK001410       GM0014    Groningen
# 4  BU001701    Haren-Zuidwest  WK001417       GM0014    Groningen
#
#    indelingswijziging_wijken_en_buurten water  meest_voorkomende_postcode  \
# 0                                     1   NEE                        9712
# 1                                     1   NEE                        9613
# 2                                     1   NEE                        9725
# 3                                     1   NEE                        9747
# 4                                     1   NEE                        9752
#
#    dekkingspercentage  omgevingsadressendichtheid  ...  \
# 0                   1                        6712  ...
# 1                   1                         170  ...
# 2                   1                        4220  ...
# 3                   1                         972  ...
# 4                   1                         951  ...
#
#    percentage_uit_marokko  percentage_uit_nederlandse_antillen_en_aruba  \
# 0                       0                                             1
# 1               -99999999                                     -99999999
# 2                       0                                             1
# 3               -99999999                                     -99999999
# 4                       0                                             1
#
#    percentage_uit_suriname  percentage_uit_turkije  \
# 0                        1                       1
# 1                -99999999               -99999999
# 2                        1                       0
# 3                -99999999               -99999999
# 4                        0                       0
#
#    percentage_overige_nietwestersemigratieachtergrond  \
# 0                                                  8
# 1                                          -99999999
# 2                                                  7
# 3                                          -99999999
# 4                                                  4
#
#    oppervlakte_totaal_in_ha  oppervlakte_land_in_ha  oppervlakte_water_in_ha  \
# 0                        39                      37                        2
# 1                        59                      52                        7
# 2                        56                      55                        1
# 3                       202                     187                       15
# 4                       141                     140                        1
#
#        jrstatcode  jaar
# 0  2022BU00140000  2022
# 1  2022BU00141406  2022
# 2  2022BU00140103  2022
# 3  2022BU00141003  2022
# 4  2022BU00141701  2022
#
# [5 rows x 41 columns]

# %%
def get_dogs_amount(row):
    dogs_row = data[data['buurtcode'] == row['buurtcode']]
    dogs = 0 if dogs_row.empty else dogs_row['dogs_amount'].iloc[0]
    return dogs

geo_data['dogs_amount'] = geo_data.apply(lambda row: get_dogs_amount(row), axis=1)
geo_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 6
#       3     dogs = 0 if dogs_row.empty else dogs_row['dogs_amount'].iloc[0]
#       4     return dogs
# ----> 6 geo_data['dogs_amount'] = geo_data.apply(lambda row: get_dogs_amount(row), axis=1)
#       7 geo_data.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:9555, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9544 from pandas.core.apply import frame_apply
#    9546 op = frame_apply(
#    9547     self,
#    9548     func=func,
#    (...)
#    9553     kwargs=kwargs,
#    9554 )
# -> 9555 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:873, in FrameApply.apply_standard(self)
#     872 def apply_standard(self):
# --> 873     results, res_index = self.apply_series_generator()
#     875     # wrap results
#     876     return self.wrap_results(results, res_index)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:889, in FrameApply.apply_series_generator(self)
#     886 with option_context("mode.chained_assignment", None):
#     887     for i, v in enumerate(series_gen):
#     888         # ignore SettingWithCopy here in case the user mutates
# --> 889         results[i] = self.f(v)
#     890         if isinstance(results[i], ABCSeries):
#     891             # If we have a view on v, we need to make a copy because
#     892             #  series_generator will swap out the underlying data
#     893             results[i] = results[i].copy(deep=False)
#
# Cell In [2], line 6, in <lambda>(row)
#       3     dogs = 0 if dogs_row.empty else dogs_row['dogs_amount'].iloc[0]
#       4     return dogs
# ----> 6 geo_data['dogs_amount'] = geo_data.apply(lambda row: get_dogs_amount(row), axis=1)
#       7 geo_data.head()
#
# Cell In [2], line 2, in get_dogs_amount(row)
#       1 def get_dogs_amount(row):
# ----> 2     dogs_row = data[data['buurtcode'] == row['buurtcode']]
#       3     dogs = 0 if dogs_row.empty else dogs_row['dogs_amount'].iloc[0]
#       4     return dogs
#
# NameError: name 'data' is not defined

# %%
# creating the bar plot
plt.bar(geo_data['buurtnaam'], geo_data['dogs_amount'], color ='maroon',
        width = 0.4)
 
plt.xlabel("Neighbourhood")
plt.ylabel("Amount of gogs")
plt.title("Dogs in different neighbourhoods of Groningen")
plt.show()

# %% [markdown]
# We can see that only 3 neighbourhoods has more than 300 dogs. Let's see who live in this neighbourhoods and if the habitants have something in common

# %%
dogs_lovers = geo_data[geo_data['dogs_amount']>300]
print(dogs_lovers.shape)
dogs_lovers.head()

# %%
print(dogs_lovers.columns)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

labels = dogs_lovers['buurtnaam'].tolist()
tot_15 = dogs_lovers['percentage_personen_0_tot_15_jaar'].tolist()
jaar_15_tot_25 = dogs_lovers['percentage_personen_15_tot_25_jaar'].tolist()
jaar_25_tot_45 = dogs_lovers['percentage_personen_25_tot_45_jaar'].tolist()
jaar_45_tot_65 = dogs_lovers['percentage_personen_45_tot_65_jaar'].tolist()
jaar_65_en_ouder = dogs_lovers['percentage_personen_65_jaar_en_ouder'].tolist()


x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width, tot_15, width, label='0 to 15')
rects2 = ax.bar(x - width, jaar_15_tot_25, width, label='15 to 25')
rects3 = ax.bar(x, jaar_25_tot_45, width, label='25 to 45')
rects4 = ax.bar(x + width, jaar_45_tot_65, width, label='45 to 65')
rects5 = ax.bar(x + 2*width, jaar_65_en_ouder, width, label='65 and older')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage')
ax.set_title("Age of population in the areas where a lot of dogs")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)

fig.tight_layout()

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

labels = dogs_lovers['buurtnaam'].tolist()
tot_15 = dogs_lovers['percentage_personen_0_tot_15_jaar'].tolist()
jaar_15_tot_25 = dogs_lovers['percentage_personen_15_tot_25_jaar'].tolist()
jaar_25_tot_45 = dogs_lovers['percentage_personen_25_tot_45_jaar'].tolist()
jaar_45_tot_65 = dogs_lovers['percentage_personen_45_tot_65_jaar'].tolist()
jaar_65_en_ouder = dogs_lovers['percentage_personen_65_jaar_en_ouder'].tolist()


x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width, tot_15, width, label='0 to 15')
rects2 = ax.bar(x - width, jaar_15_tot_25, width, label='15 to 25')
rects3 = ax.bar(x, jaar_25_tot_45, width, label='25 to 45')
rects4 = ax.bar(x + width, jaar_45_tot_65, width, label='45 to 65')
rects5 = ax.bar(x + 2*width, jaar_65_en_ouder, width, label='65 and older')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage')
ax.set_title("Age of population in the areas where a lot of dogs")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)

fig.tight_layout()

plt.show()
