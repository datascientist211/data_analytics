# %%
import pandas as pd 
data_national = pd.read_csv('migrants_in_years.csv', sep = ';')
data_national = data_national.rename(columns={'Migratieachtergrond': 'MigratieachtergrondId'})
#data_wijk_stadsdeelcode['wijkcode'] = data_wijk_stadsdeelcode['wijkcode'].str.replace('\D', '', regex=True)
#data_wijk_stadsdeelcode = data_wijk_stadsdeelcode.drop_duplicates(subset=["wijkcode"], keep='first')
print(data_national.shape)
data_national.head()
# Out:
# (7128, 8)
#    ID Geslacht  Leeftijd BurgerlijkeStaat Generatie MigratieachtergrondId  \
# 0   0  T001038     10000          T001019   T001040               T001040
# 1   1  T001038     10000          T001019   T001040               T001040
# 2   2  T001038     10000          T001019   T001040               T001040
# 3   3  T001038     10000          T001019   T001040               T001040
# 4   4  T001038     10000          T001019   T001040               T001040
#
#    Perioden  Bevolking_1
# 0  1996JJ00   15493889.0
# 1  1997JJ00   15567107.0
# 2  1998JJ00   15654192.0
# 3  1999JJ00   15760225.0
# 4  2000JJ00   15863950.0

# %%
metadata_national = pd.read_csv('migrants_in_years_metadata.csv')
#data_wijk_stadsdeelcode = data_wijk_stadsdeelcode[['Wijkcode', 'Stadsdeelcode']]
#data_wijk_stadsdeelcode = data_wijk_stadsdeelcode.rename(columns={'Wijkcode': 'wijkcode'})
#data_wijk_stadsdeelcode['wijkcode'] = data_wijk_stadsdeelcode['wijkcode'].str.replace('\D', '', regex=True)
#data_wijk_stadsdeelcode = data_wijk_stadsdeelcode.drop_duplicates(subset=["wijkcode"], keep='first')

print(metadata_national.shape)
metadata_national.head()
# Out:
# (456, 21)
#                ID                                              Title  \
# 0               0  Bevolking; geslacht, lft, generatie en migr.ac...
# 1  DataProperties                                                NaN
# 2              ID                                           Position
# 3               0                                                  0
# 4               1                                                  1
#
#                                ShortTitle Identifier  \
# 0  Bevolking; migr.achtergrond; 1996-2022      37325
# 1                                     NaN        NaN
# 2                                ParentID       Type
# 3                                     NaN  Dimension
# 4                                     NaN  Dimension
#
#                                              Summary            Modified  \
# 0  Bevolking naar geslacht, leeftijd, burgerlijke...  2022-05-31 2:00:00
# 1                                                NaN                 NaN
# 2                                                Key               Title
# 3                                           Geslacht            Geslacht
# 4                                           Leeftijd            Leeftijd
#
#   ReasonDelivery ExplanatoryText  Language Catalog  ...       Period  \
# 0      Stopgezet             NaN        nl     CBS  ...  1996 - 2022
# 1            NaN             NaN       NaN     NaN  ...          NaN
# 2    Description   ReleasePolicy  Datatype    Unit  ...      Default
# 3            NaN             NaN       NaN     NaN  ...          NaN
# 4            NaN             NaN       NaN     NaN  ...          NaN
#
#                                     ShortDescription  \
# 0  \nBevolking van Nederland op 1 januari naar ge...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Description  \
# 0  INHOUDSOPGAVE\n\n1. Toelichting\n2. Definities...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                  DefaultPresentation  \
# 0  ts=1665754302145&graphtype=Table&r=Migratieach...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                     DefaultSelection      GraphTypes  \
# 0  $filter=((Geslacht eq 'T001038')) and ((Leefti...  Table,Bar,Line
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#        OutputStatus Source    MetaDataModified SearchPriority
# 0  Gediscontinueerd   CBS.  2023-01-13 2:00:00            1.0
# 1               NaN    NaN                 NaN            NaN
# 2               NaN    NaN                 NaN            NaN
# 3               NaN    NaN                 NaN            NaN
# 4               NaN    NaN                 NaN            NaN
#
# [5 rows x 21 columns]

# %%
def get_nationaliteit(row):
    data_row = metadata_national[metadata_national['ID'] == row['MigratieachtergrondId']]
    value = "" if data_row.empty else data_row['Title'].iloc[0]
    return value
    
def get_year(row):
    data_row = metadata_national[metadata_national['ID'] == row['Perioden']]
    value = "" if data_row.empty else data_row['Title'].iloc[0]
    return value
    

data_national = data_national.copy()

data_national['Migratieachtergrond'] = data_national.apply(lambda row: get_nationaliteit(row), axis=1)
data_national['Jaar'] = data_national.apply(lambda row: get_year(row), axis=1)

print(data_national.shape)
data_national.head()
# Out:
# (7128, 10)
#    ID Geslacht  Leeftijd BurgerlijkeStaat Generatie MigratieachtergrondId  \
# 0   0  T001038     10000          T001019   T001040               T001040
# 1   1  T001038     10000          T001019   T001040               T001040
# 2   2  T001038     10000          T001019   T001040               T001040
# 3   3  T001038     10000          T001019   T001040               T001040
# 4   4  T001038     10000          T001019   T001040               T001040
#
#    Perioden  Bevolking_1 Migratieachtergrond  Jaar
# 0  1996JJ00   15493889.0              Totaal  1996
# 1  1997JJ00   15567107.0              Totaal  1997
# 2  1998JJ00   15654192.0              Totaal  1998
# 3  1999JJ00   15760225.0              Totaal  1999
# 4  2000JJ00   15863950.0              Totaal  2000

# %%
data_national = data_national[['MigratieachtergrondId','Migratieachtergrond', 'Jaar', 'Bevolking_1']]
data_national.to_csv(r'amsterdamers_nationaliteit.csv', index = False)
data_national.to_excel('amsterdamers_nationaliteit.xlsx', index = None, header=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 data_national = data_national[['NationaliteitId','Nationaliteit', 'Bevolking_1']]
#       2 data_national.to_csv(r'amsterdamers_nationaliteit.csv', index = False)
#       3 data_national.to_excel('amsterdamers_nationaliteit.xlsx', index = None, header=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6174, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['NationaliteitId', 'Nationaliteit'] not in index"
