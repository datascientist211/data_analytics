# %%
import pandas as pd 
import geopandas as gpd

# reading database
geo_data = gpd.GeoDataFrame(gpd.read_file("WijkBuurtkaart_2021_v2/wijkenbuurten_2021_v2.gpkg"))
#convert Rijksdriehoeksmeting (RD) GIS coordinates format to Lat/Long 
geo_data.set_crs(epsg='28992')
geo_data = geo_data.to_crs(epsg='4326')

# get the only data we need 
geo_data = geo_data[geo_data['gemeentenaam'] == "Amsterdam"]
geo_data = geo_data[geo_data['buurtnaam'] != " "]
data_buurt = pd.DataFrame(geo_data.drop(columns='geometry', axis = 1))
geo_data = geo_data[['geometry', 'buurtcode']]

# write it down to the .csv file
geo_data.to_csv(r'geodata_amsterdam.csv', index = False)

print(geo_data.shape)
geo_data.head()
# Out:
# (479, 2)
#                                                geometry   buurtcode
# 4121  MULTIPOLYGON (((4.90096 52.37724, 4.90195 52.3...  BU03630000
# 4122  MULTIPOLYGON (((4.89651 52.37575, 4.89707 52.3...  BU03630001
# 4123  MULTIPOLYGON (((4.89966 52.37468, 4.90002 52.3...  BU03630002
# 4124  MULTIPOLYGON (((4.89301 52.37271, 4.89331 52.3...  BU03630003
# 4125  MULTIPOLYGON (((4.89613 52.37177, 4.89670 52.3...  BU03630004

# %%
print(data_buurt.shape)
data_buurt.head()
# Out:
# (479, 144)
#        buurtcode        buurtnaam  wijkcode gemeentecode gemeentenaam  \
# 4121  BU03630000      Kop Zeedijk  WK036300       GM0363    Amsterdam
# 4122  BU03630001   Oude Kerk e.o.  WK036300       GM0363    Amsterdam
# 4123  BU03630002  Burgwallen Oost  WK036300       GM0363    Amsterdam
# 4124  BU03630003         Nes e.o.  WK036300       GM0363    Amsterdam
# 4125  BU03630004  BG-terrein e.o.  WK036300       GM0363    Amsterdam
#
#       indelingswijziging_wijken_en_buurten water meest_voorkomende_postcode  \
# 4121                                     1   NEE                       1012
# 4122                                     1   NEE                       1012
# 4123                                     1   NEE                       1012
# 4124                                     1   NEE                       1012
# 4125                                     1   NEE                       1012
#
#       dekkingspercentage  omgevingsadressendichtheid  ...  \
# 4121                   1                        6776  ...
# 4122                   1                        7430  ...
# 4123                   1                        7559  ...
# 4124                   1                        9947  ...
# 4125                   1                        8489  ...
#
#       bioscoop_gemiddeld_aantal_binnen_10_km  \
# 4121                                    14.0
# 4122                                    14.0
# 4123                                    14.0
# 4124                                    14.0
# 4125                                    14.0
#
#       bioscoop_gemiddeld_aantal_binnen_20_km  sauna_gemiddelde_afstand_in_km  \
# 4121                                    21.0                             0.6
# 4122                                    21.0                             0.5
# 4123                                    20.6                             0.3
# 4124                                    20.6                             0.3
# 4125                                    20.2                             0.2
#
#       zonnebank_gemiddelde_afstand_in_km  \
# 4121                                 1.6
# 4122                                 1.5
# 4123                                 1.6
# 4124                                 1.3
# 4125                                 1.4
#
#       attractiepark_gemiddelde_afstand_in_km  \
# 4121                                     1.1
# 4122                                     1.1
# 4123                                     0.8
# 4124                                     1.0
# 4125                                     0.8
#
#       attractiepark_gemiddeld_aantal_binnen_10_km  \
# 4121                                          9.0
# 4122                                          9.0
# 4123                                          9.0
# 4124                                          9.0
# 4125                                          9.0
#
#       attractiepark_gemiddeld_aantal_binnen_20_km  \
# 4121                                         17.0
# 4122                                         17.0
# 4123                                         17.0
# 4124                                         17.0
# 4125                                         17.0
#
#       attractiepark_gemiddeld_aantal_binnen_50_km      jrstatcode  jaar
# 4121                                         67.2  2021BU03630000  2021
# 4122                                         66.9  2021BU03630001  2021
# 4123                                         67.0  2021BU03630002  2021
# 4124                                         67.4  2021BU03630003  2021
# 4125                                         67.2  2021BU03630004  2021
#
# [5 rows x 144 columns]

# %%
data_buurt.columns.to_list()
# Out:
# ['buurtcode',
#  'buurtnaam',
#  'wijkcode',
#  'gemeentecode',
#  'gemeentenaam',
#  'indelingswijziging_wijken_en_buurten',
#  'water',
#  'meest_voorkomende_postcode',
#  'dekkingspercentage',
#  'omgevingsadressendichtheid',
#  'stedelijkheid_adressen_per_km2',
#  'bevolkingsdichtheid_inwoners_per_km2',
#  'aantal_inwoners',
#  'mannen',
#  'vrouwen',
#  'percentage_personen_0_tot_15_jaar',
#  'percentage_personen_15_tot_25_jaar',
#  'percentage_personen_25_tot_45_jaar',
#  'percentage_personen_45_tot_65_jaar',
#  'percentage_personen_65_jaar_en_ouder',
#  'percentage_ongehuwd',
#  'percentage_gehuwd',
#  'percentage_gescheid',
#  'percentage_verweduwd',
#  'geboorte_totaal',
#  'geboortes_per_1000_inwoners',
#  'sterfte_totaal',
#  'sterfte_relatief',
#  'aantal_huishoudens',
#  'percentage_eenpersoonshuishoudens',
#  'percentage_huishoudens_zonder_kinderen',
#  'percentage_huishoudens_met_kinderen',
#  'gemiddelde_huishoudsgrootte',
#  'percentage_westerse_migratieachtergrond',
#  'percentage_niet_westerse_migratieachtergrond',
#  'percentage_uit_marokko',
#  'percentage_uit_nederlandse_antillen_en_aruba',
#  'percentage_uit_suriname',
#  'percentage_uit_turkije',
#  'percentage_overige_nietwestersemigratieachtergrond',
#  'aantal_bedrijven_landbouw_bosbouw_visserij',
#  'aantal_bedrijven_nijverheid_energie',
#  'aantal_bedrijven_handel_en_horeca',
#  'aantal_bedrijven_vervoer_informatie_communicatie',
#  'aantal_bedrijven_financieel_onroerend_goed',
#  'aantal_bedrijven_zakelijke_dienstverlening',
#  'aantal_bedrijven_overheid_onderwijs_en_zorg',
#  'aantal_bedrijven_cultuur_recreatie_overige',
#  'aantal_bedrijfsvestigingen',
#  'woningvoorraad',
#  'gemiddelde_woningwaarde',
#  'percentage_eengezinswoning',
#  'percentage_meergezinswoning',
#  'percentage_bewoond',
#  'percentage_koopwoningen',
#  'percentage_huurwoningen',
#  'perc_huurwoningen_in_bezit_woningcorporaties',
#  'perc_huurwoningen_in_bezit_overige_verhuurders',
#  'percentage_woningen_met_eigendom_onbekend',
#  'percentage_bouwjaarklasse_tot_2000',
#  'percentage_bouwjaarklasse_vanaf_2000',
#  'percentage_leegstand_woningen',
#  'personenautos_totaal',
#  'personenautos_per_huishouden',
#  'personenautos_per_km2',
#  'motortweewielers_totaal',
#  'aantal_personenautos_met_brandstof_benzine',
#  'aantal_personenautos_met_overige_brandstof',
#  'oppervlakte_totaal_in_ha',
#  'oppervlakte_land_in_ha',
#  'oppervlakte_water_in_ha',
#  'huisartsenpraktijk_gemiddelde_afstand_in_km',
#  'huisartsenpraktijk_gemiddeld_aantal_binnen_1_km',
#  'huisartsenpraktijk_gemiddeld_aantal_binnen_3_km',
#  'huisartsenpraktijk_gemiddeld_aantal_binnen_5_km',
#  'apotheek_gemiddelde_afstand_in_km',
#  'grote_supermarkt_gemiddelde_afstand_in_km',
#  'grote_supermarkt_gemiddeld_aantal_binnen_1_km',
#  'grote_supermarkt_gemiddeld_aantal_binnen_3_km',
#  'grote_supermarkt_gemiddeld_aantal_binnen_5_km',
#  'winkels_ov_dagelijkse_levensm_gem_afst_in_km',
#  'winkels_ov_dagel_levensm_gem_aantal_binnen_1_km',
#  'winkels_ov_dagel_levensm_gem_aantal_binnen_3_km',
#  'winkels_ov_dagel_levensm_gem_aantal_binnen_5_km',
#  'warenhuis_gemiddelde_afstand_in_km',
#  'warenhuis_gemiddeld_aantal_binnen_5_km',
#  'warenhuis_gemiddeld_aantal_binnen_10_km',
#  'warenhuis_gemiddeld_aantal_binnen_20_km',
#  'cafe_gemiddelde_afstand_in_km',
#  'cafe_gemiddeld_aantal_binnen_1_km',
#  'cafe_gemiddeld_aantal_binnen_3_km',
#  'cafe_gemiddeld_aantal_binnen_5_km',
#  'cafetaria_gemiddelde_afstand_in_km',
#  'cafetaria_gemiddeld_aantal_binnen_1_km',
#  'cafetaria_gemiddeld_aantal_binnen_3_km',
#  'cafetaria_gemiddeld_aantal_binnen_5_km',
#  'restaurant_gemiddelde_afstand_in_km',
#  'restaurant_gemiddeld_aantal_binnen_1_km',
#  'restaurant_gemiddeld_aantal_binnen_3_km',
#  'restaurant_gemiddeld_aantal_binnen_5_km',
#  'hotel_gemiddelde_afstand_in_km',
#  'hotel_gemiddeld_aantal_binnen_5_km',
#  'hotel_gemiddeld_aantal_binnen_10_km',
#  'hotel_gemiddeld_aantal_binnen_20_km',
#  'kinderdagverblijf_gemiddelde_afstand_in_km',
#  'kinderdagverblijf_gemiddeld_aantal_binnen_1_km',
#  'kinderdagverblijf_gemiddeld_aantal_binnen_3_km',
#  'kinderdagverblijf_gemiddeld_aantal_binnen_5_km',
#  'buitenschoolse_opvang_gem_afstand_in_km',
#  'buitenschoolse_opvang_gemiddeld_aantal_binnen_1_km',
#  'buitenschoolse_opvang_gemiddeld_aantal_binnen_3_km',
#  'buitenschoolse_opvang_gemiddeld_aantal_binnen_5_km',
#  'basisonderwijs_gemiddelde_afstand_in_km',
#  'basisonderwijs_gemiddeld_aantal_binnen_1_km',
#  'basisonderwijs_gemiddeld_aantal_binnen_3_km',
#  'basisonderwijs_gemiddeld_aantal_binnen_5_km',
#  'voortgezet_onderwijs_gem_afstand_in_km',
#  'voortgezet_onderwijs_gemiddeld_aantal_binnen_3_km',
#  'voortgezet_onderwijs_gemiddeld_aantal_binnen_5_km',
#  'voortgezet_onderwijs_gemiddeld_aantal_binnen_10_km',
#  'vmbo_gemiddelde_afstand_in_km',
#  'vmbo_gemiddeld_aantal_binnen_3_km',
#  'vmbo_gemiddeld_aantal_binnen_5_km',
#  'vmbo_gemiddeld_aantal_binnen_10_km',
#  'havo_vwo_gemiddelde_afstand_in_km',
#  'havo_vwo_gemiddeld_aantal_binnen_3_km',
#  'havo_vwo_gemiddeld_aantal_binnen_5_km',
#  'havo_vwo_gemiddeld_aantal_binnen_10_km',
#  'brandweerkazerne_gemiddelde_afstand_in_km',
#  'zwembad_gemiddelde_afstand_in_km',
#  'kunstijsbaan_gemiddelde_afstand_in_km',
#  'bibliotheek_gemiddelde_afstand_in_km',
#  'bioscoop_gemiddelde_afstand_in_km',
#  'bioscoop_gemiddeld_aantal_binnen_5_km',
#  'bioscoop_gemiddeld_aantal_binnen_10_km',
#  'bioscoop_gemiddeld_aantal_binnen_20_km',
#  'sauna_gemiddelde_afstand_in_km',
#  'zonnebank_gemiddelde_afstand_in_km',
#  'attractiepark_gemiddelde_afstand_in_km',
#  'attractiepark_gemiddeld_aantal_binnen_10_km',
#  'attractiepark_gemiddeld_aantal_binnen_20_km',
#  'attractiepark_gemiddeld_aantal_binnen_50_km',
#  'jrstatcode',
#  'jaar']

# %%
data = data_buurt.copy()
data.drop('gemeentecode', axis=1, inplace = True)
data.drop('gemeentenaam', axis=1, inplace = True)
data.drop('indelingswijziging_wijken_en_buurten', axis=1, inplace = True)
data.drop('water', axis=1, inplace = True)
data.drop('meest_voorkomende_postcode', axis=1, inplace = True)
data.drop('dekkingspercentage', axis=1, inplace = True)
data.drop('omgevingsadressendichtheid', axis=1, inplace = True)
data.drop('stedelijkheid_adressen_per_km2', axis=1, inplace = True)
data.drop('geboorte_totaal', axis=1, inplace = True)
data.drop('sterfte_totaal', axis=1, inplace = True)
data.drop('sterfte_relatief', axis=1, inplace = True)
data.drop('oppervlakte_totaal_in_ha', axis=1, inplace = True)
data.drop('oppervlakte_land_in_ha', axis=1, inplace = True)
data.drop('oppervlakte_water_in_ha', axis=1, inplace = True)
data.drop('attractiepark_gemiddeld_aantal_binnen_10_km', axis=1, inplace = True)
data.drop('attractiepark_gemiddeld_aantal_binnen_20_km', axis=1, inplace = True)
data.drop('attractiepark_gemiddeld_aantal_binnen_50_km', axis=1, inplace = True)
data.drop('jrstatcode', axis=1, inplace = True)
data.drop('jaar', axis=1, inplace = True)
#data.columns.to_list()

# %%
data.replace(to_replace="X", value="0", inplace=True)
data.replace(to_replace="-", value="0", inplace=True)
data.replace(to_replace=-99999999, value=0, inplace=True)

for col_name in data.select_dtypes(include=[object]):
    data[col_name] = data[col_name].str.replace(',','.')
    
data.fillna(0, inplace=True)
cols=[i for i in data.columns if i not in ["wijkcode","buurtnaam","buurtcode"]]
for col in cols:
    data[col]=pd.to_numeric(data[col])

# %%
print(data.dtypes.to_list())
# Out:
# [dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('float64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('float64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64')]

# %%
new_data = pd.read_csv('wijken.csv', sep = ";")
print(new_data.shape)
new_data.head()
# Out:
# (3417, 143)
#   fid geom  wijkcode wijknaam gemeentecode     gemeentenaam  \
# 0   1   GP  WK003499                GM0034           Almere
# 1   2   GP  WK005099                GM0050         Zeewolde
# 2   3   GP  WK006099                GM0060          Ameland
# 3   4   GP  WK007299                GM0072        Harlingen
# 4   5   GP  WK008899                GM0088  Schiermonnikoog
#
#   indelingswijziging_wijken_en_buurten water  omgevingsadressendichtheid  \
# 0                            -99999999    JA                 -99999999.0
# 1                            -99999999    JA                 -99999999.0
# 2                            -99999999    JA                 -99999999.0
# 3                            -99999999    JA                 -99999999.0
# 4                            -99999999    JA                 -99999999.0
#
#    stedelijkheid_adressen_per_km2  ...  \
# 0                     -99999999.0  ...
# 1                     -99999999.0  ...
# 2                     -99999999.0  ...
# 3                     -99999999.0  ...
# 4                     -99999999.0  ...
#
#    bioscoop_gemiddeld_aantal_binnen_10_km  \
# 0                             -99999999.0
# 1                             -99999999.0
# 2                             -99999999.0
# 3                             -99999999.0
# 4                             -99999999.0
#
#    bioscoop_gemiddeld_aantal_binnen_20_km  sauna_gemiddelde_afstand_in_km  \
# 0                             -99999999.0                     -99999999.0
# 1                             -99999999.0                     -99999999.0
# 2                             -99999999.0                     -99999999.0
# 3                             -99999999.0                     -99999999.0
# 4                             -99999999.0                     -99999999.0
#
#    zonnebank_gemiddelde_afstand_in_km  attractiepark_gemiddelde_afstand_in_km  \
# 0                         -99999999.0                             -99999999.0
# 1                         -99999999.0                             -99999999.0
# 2                         -99999999.0                             -99999999.0
# 3                         -99999999.0                             -99999999.0
# 4                         -99999999.0                             -99999999.0
#
#    attractiepark_gemiddeld_aantal_binnen_10_km  \
# 0                                  -99999999.0
# 1                                  -99999999.0
# 2                                  -99999999.0
# 3                                  -99999999.0
# 4                                  -99999999.0
#
#    attractiepark_gemiddeld_aantal_binnen_20_km  \
# 0                                  -99999999.0
# 1                                  -99999999.0
# 2                                  -99999999.0
# 3                                  -99999999.0
# 4                                  -99999999.0
#
#    attractiepark_gemiddeld_aantal_binnen_50_km    jrstatcode    jaar
# 0                                  -99999999.0  2021WK003499  2021.0
# 1                                  -99999999.0  2021WK005099  2021.0
# 2                                  -99999999.0  2021WK006099  2021.0
# 3                                  -99999999.0  2021WK007299  2021.0
# 4                                  -99999999.0  2021WK008899  2021.0
#
# [5 rows x 143 columns]

# %%
data_wijk = new_data[new_data['gemeentenaam'] == "Amsterdam"]
data_wijk = data_wijk[data_wijk['wijknaam'] != ' ']
data_wijk = data_wijk[['wijkcode', 'wijknaam']]
print(data_wijk.shape)
data_wijk.head()
# Out:
# (99, 2)
#      wijkcode                 wijknaam
# 905  WK036300    Burgwallen-Oude Zijde
# 906  WK036301  Burgwallen-Nieuwe Zijde
# 907  WK036302      Grachtengordel-West
# 908  WK036303      Grachtengordel-Zuid
# 909  WK036304       Nieuwmarkt/Lastage

# %%
#data = pd.merge(data, data_wijk, on="wijkcode")
def get_wijk(row):
    data_row = data_wijk[data_wijk['wijkcode'] == row['wijkcode']]
    value = "" if data_row.empty else data_row['wijknaam'].iloc[0]
    return value
    

data = data.copy()

data['wijknaam'] = data.apply(lambda row: get_wijk(row), axis=1)
print(data.shape)
data.head()
# Out:
# (479, 126)
#        buurtcode        buurtnaam  wijkcode  \
# 4121  BU03630000      Kop Zeedijk  WK036300
# 4122  BU03630001   Oude Kerk e.o.  WK036300
# 4123  BU03630002  Burgwallen Oost  WK036300
# 4124  BU03630003         Nes e.o.  WK036300
# 4125  BU03630004  BG-terrein e.o.  WK036300
#
#       bevolkingsdichtheid_inwoners_per_km2  aantal_inwoners  mannen  vrouwen  \
# 4121                                 18567             1115     650      465
# 4122                                  7756              695     390      305
# 4123                                 27483             1650     860      790
# 4124                                  7360              370     205      165
# 4125                                  8638              695     385      310
#
#       percentage_personen_0_tot_15_jaar  percentage_personen_15_tot_25_jaar  \
# 4121                                  4                                  13
# 4122                                  3                                  21
# 4123                                  5                                  17
# 4124                                  6                                  17
# 4125                                  5                                  20
#
#       percentage_personen_25_tot_45_jaar  ...  \
# 4121                                  50  ...
# 4122                                  49  ...
# 4123                                  47  ...
# 4124                                  51  ...
# 4125                                  42  ...
#
#       kunstijsbaan_gemiddelde_afstand_in_km  \
# 4121                                    5.3
# 4122                                    5.4
# 4123                                    5.2
# 4124                                    5.3
# 4125                                    5.1
#
#       bibliotheek_gemiddelde_afstand_in_km  bioscoop_gemiddelde_afstand_in_km  \
# 4121                                   0.9                                1.2
# 4122                                   1.2                                1.0
# 4123                                   1.1                                0.9
# 4124                                   1.5                                0.6
# 4125                                   1.4                                0.6
#
#       bioscoop_gemiddeld_aantal_binnen_5_km  \
# 4121                                   12.0
# 4122                                   12.0
# 4123                                   12.0
# 4124                                   11.4
# 4125                                   12.0
#
#       bioscoop_gemiddeld_aantal_binnen_10_km  \
# 4121                                    14.0
# 4122                                    14.0
# 4123                                    14.0
# 4124                                    14.0
# 4125                                    14.0
#
#       bioscoop_gemiddeld_aantal_binnen_20_km  sauna_gemiddelde_afstand_in_km  \
# 4121                                    21.0                             0.6
# 4122                                    21.0                             0.5
# 4123                                    20.6                             0.3
# 4124                                    20.6                             0.3
# 4125                                    20.2                             0.2
#
#       zonnebank_gemiddelde_afstand_in_km  \
# 4121                                 1.6
# 4122                                 1.5
# 4123                                 1.6
# 4124                                 1.3
# 4125                                 1.4
#
#       attractiepark_gemiddelde_afstand_in_km               wijknaam
# 4121                                     1.1  Burgwallen-Oude Zijde
# 4122                                     1.1  Burgwallen-Oude Zijde
# 4123                                     0.8  Burgwallen-Oude Zijde
# 4124                                     1.0  Burgwallen-Oude Zijde
# 4125                                     0.8  Burgwallen-Oude Zijde
#
# [5 rows x 126 columns]

# %%
data['wijkcode'] = data['wijkcode'].astype(str).str.replace('WK0363', '')
data.head()
# Out:
#        buurtcode        buurtnaam wijkcode  \
# 4121  BU03630000      Kop Zeedijk       00
# 4122  BU03630001   Oude Kerk e.o.       00
# 4123  BU03630002  Burgwallen Oost       00
# 4124  BU03630003         Nes e.o.       00
# 4125  BU03630004  BG-terrein e.o.       00
#
#       bevolkingsdichtheid_inwoners_per_km2  aantal_inwoners  mannen  vrouwen  \
# 4121                                 18567             1115     650      465
# 4122                                  7756              695     390      305
# 4123                                 27483             1650     860      790
# 4124                                  7360              370     205      165
# 4125                                  8638              695     385      310
#
#       percentage_personen_0_tot_15_jaar  percentage_personen_15_tot_25_jaar  \
# 4121                                  4                                  13
# 4122                                  3                                  21
# 4123                                  5                                  17
# 4124                                  6                                  17
# 4125                                  5                                  20
#
#       percentage_personen_25_tot_45_jaar  ...  \
# 4121                                  50  ...
# 4122                                  49  ...
# 4123                                  47  ...
# 4124                                  51  ...
# 4125                                  42  ...
#
#       kunstijsbaan_gemiddelde_afstand_in_km  \
# 4121                                    5.3
# 4122                                    5.4
# 4123                                    5.2
# 4124                                    5.3
# 4125                                    5.1
#
#       bibliotheek_gemiddelde_afstand_in_km  bioscoop_gemiddelde_afstand_in_km  \
# 4121                                   0.9                                1.2
# 4122                                   1.2                                1.0
# 4123                                   1.1                                0.9
# 4124                                   1.5                                0.6
# 4125                                   1.4                                0.6
#
#       bioscoop_gemiddeld_aantal_binnen_5_km  \
# 4121                                   12.0
# 4122                                   12.0
# 4123                                   12.0
# 4124                                   11.4
# 4125                                   12.0
#
#       bioscoop_gemiddeld_aantal_binnen_10_km  \
# 4121                                    14.0
# 4122                                    14.0
# 4123                                    14.0
# 4124                                    14.0
# 4125                                    14.0
#
#       bioscoop_gemiddeld_aantal_binnen_20_km  sauna_gemiddelde_afstand_in_km  \
# 4121                                    21.0                             0.6
# 4122                                    21.0                             0.5
# 4123                                    20.6                             0.3
# 4124                                    20.6                             0.3
# 4125                                    20.2                             0.2
#
#       zonnebank_gemiddelde_afstand_in_km  \
# 4121                                 1.6
# 4122                                 1.5
# 4123                                 1.6
# 4124                                 1.3
# 4125                                 1.4
#
#       attractiepark_gemiddelde_afstand_in_km               wijknaam
# 4121                                     1.1  Burgwallen-Oude Zijde
# 4122                                     1.1  Burgwallen-Oude Zijde
# 4123                                     0.8  Burgwallen-Oude Zijde
# 4124                                     1.0  Burgwallen-Oude Zijde
# 4125                                     0.8  Burgwallen-Oude Zijde
#
# [5 rows x 126 columns]

# %%
import re
data_wijk_stadsdeelcode = pd.read_csv('GEBIED_BUURTEN.csv', sep = ";")
data_wijk_stadsdeelcode = data_wijk_stadsdeelcode[['Wijkcode', 'Stadsdeelcode']]
data_wijk_stadsdeelcode = data_wijk_stadsdeelcode.rename(columns={'Wijkcode': 'wijkcode'})
data_wijk_stadsdeelcode['wijkcode'] = data_wijk_stadsdeelcode['wijkcode'].str.replace('\D', '', regex=True)
data_wijk_stadsdeelcode = data_wijk_stadsdeelcode.drop_duplicates(subset=["wijkcode"], keep='first')

print(data_wijk_stadsdeelcode.shape)
data_wijk_stadsdeelcode.head()
# Out:
# (100, 2)
#    wijkcode Stadsdeelcode
# 0        00             A
# 3        01             A
# 11       02             A
# 14       03             A
# 21       04             A

# %%
data_stadsdelen = pd.read_csv('GEBIED_STADSDELEN.csv', sep = ";")
data_stadsdelen = data_stadsdelen[['Stadsdeelcode', 'Stadsdeelnaam']]
data_stadsdelen = data_stadsdelen.rename(columns={'Stadsdeelnaam': 'stadsdeel'})
#print(data_stadsdelen.shape)
data_stadsdelen.head()
# Out:
#   Stadsdeelcode   stadsdeel
# 0             A     Centrum
# 1             B   Westpoort
# 2             E        West
# 3             F  Nieuw-West
# 4             K        Zuid

# %%
print(data_stadsdelen.shape)
data_stadsdelen = pd.merge(data_stadsdelen, data_wijk_stadsdeelcode, on="Stadsdeelcode")
print(data_stadsdelen.shape)
data_stadsdelen.head()
# Out:
# (9, 2)
# (100, 3)
#   Stadsdeelcode stadsdeel wijkcode
# 0             A   Centrum       00
# 1             A   Centrum       01
# 2             A   Centrum       02
# 3             A   Centrum       03
# 4             A   Centrum       04

# %%
#data = pd.merge(data, data_wijk, on="wijkcode")
def get_stadsdeel(row):
    #print("wijkcode: " +  row['wijkcode'] + " stadsdeel: " + )
    data_row = data_stadsdelen[data_stadsdelen['wijkcode'] == row['wijkcode']]
    value = "" if data_row.empty else data_row['stadsdeel'].iloc[0]
    return value
    

data = data.copy()

data['stadsdeel'] = data.apply(lambda row: get_stadsdeel(row), axis=1)
print(data.shape)
data.head()
# Out:
# (479, 127)
#        buurtcode        buurtnaam wijkcode  \
# 4121  BU03630000      Kop Zeedijk       00
# 4122  BU03630001   Oude Kerk e.o.       00
# 4123  BU03630002  Burgwallen Oost       00
# 4124  BU03630003         Nes e.o.       00
# 4125  BU03630004  BG-terrein e.o.       00
#
#       bevolkingsdichtheid_inwoners_per_km2  aantal_inwoners  mannen  vrouwen  \
# 4121                                 18567             1115     650      465
# 4122                                  7756              695     390      305
# 4123                                 27483             1650     860      790
# 4124                                  7360              370     205      165
# 4125                                  8638              695     385      310
#
#       percentage_personen_0_tot_15_jaar  percentage_personen_15_tot_25_jaar  \
# 4121                                  4                                  13
# 4122                                  3                                  21
# 4123                                  5                                  17
# 4124                                  6                                  17
# 4125                                  5                                  20
#
#       percentage_personen_25_tot_45_jaar  ...  \
# 4121                                  50  ...
# 4122                                  49  ...
# 4123                                  47  ...
# 4124                                  51  ...
# 4125                                  42  ...
#
#       bibliotheek_gemiddelde_afstand_in_km  bioscoop_gemiddelde_afstand_in_km  \
# 4121                                   0.9                                1.2
# 4122                                   1.2                                1.0
# 4123                                   1.1                                0.9
# 4124                                   1.5                                0.6
# 4125                                   1.4                                0.6
#
#       bioscoop_gemiddeld_aantal_binnen_5_km  \
# 4121                                   12.0
# 4122                                   12.0
# 4123                                   12.0
# 4124                                   11.4
# 4125                                   12.0
#
#       bioscoop_gemiddeld_aantal_binnen_10_km  \
# 4121                                    14.0
# 4122                                    14.0
# 4123                                    14.0
# 4124                                    14.0
# 4125                                    14.0
#
#       bioscoop_gemiddeld_aantal_binnen_20_km  sauna_gemiddelde_afstand_in_km  \
# 4121                                    21.0                             0.6
# 4122                                    21.0                             0.5
# 4123                                    20.6                             0.3
# 4124                                    20.6                             0.3
# 4125                                    20.2                             0.2
#
#       zonnebank_gemiddelde_afstand_in_km  \
# 4121                                 1.6
# 4122                                 1.5
# 4123                                 1.6
# 4124                                 1.3
# 4125                                 1.4
#
#       attractiepark_gemiddelde_afstand_in_km               wijknaam  stadsdeel
# 4121                                     1.1  Burgwallen-Oude Zijde    Centrum
# 4122                                     1.1  Burgwallen-Oude Zijde    Centrum
# 4123                                     0.8  Burgwallen-Oude Zijde    Centrum
# 4124                                     1.0  Burgwallen-Oude Zijde    Centrum
# 4125                                     0.8  Burgwallen-Oude Zijde    Centrum
#
# [5 rows x 127 columns]

# %%
empty_data = data[data['stadsdeel'] == '']
empty_data.shape
# Out:
# (0, 127)

# %%
data.to_csv(r'amsterdam_buurten.csv', index = False)

# %%
data_national = pd.read_csv('Nationalitiet_data.csv', sep = ';')
data_national = data_national[data_national['Leeftijd'] == 10000] 
data_national = data_national.rename(columns={'Nationaliteit': 'NationaliteitId'})
#data_wijk_stadsdeelcode['wijkcode'] = data_wijk_stadsdeelcode['wijkcode'].str.replace('\D', '', regex=True)
#data_wijk_stadsdeelcode = data_wijk_stadsdeelcode.drop_duplicates(subset=["wijkcode"], keep='first')
print(data_national.shape)
data_national.head()
# Out:
# (45, 7)
#       ID Geslacht  Leeftijd NationaliteitId  RegioS  Perioden  Bevolking_1
# 0   2350  T001038     10000         T001059  GM0363  2021JJ00       873338
# 1  24302  T001038     10000         NAT9489  GM0363  2021JJ00       162462
# 2  46254  T001038     10000         NAT9267  GM0363  2021JJ00       710876
# 3  68206  T001038     10000         NAT9269  GM0363  2021JJ00        16905
# 4  90158  T001038     10000         NAT9270  GM0363  2021JJ00        15636

# %%
metadata_national = pd.read_csv('Nationalitiet_metadata.csv')
#data_wijk_stadsdeelcode = data_wijk_stadsdeelcode[['Wijkcode', 'Stadsdeelcode']]
#data_wijk_stadsdeelcode = data_wijk_stadsdeelcode.rename(columns={'Wijkcode': 'wijkcode'})
#data_wijk_stadsdeelcode['wijkcode'] = data_wijk_stadsdeelcode['wijkcode'].str.replace('\D', '', regex=True)
#data_wijk_stadsdeelcode = data_wijk_stadsdeelcode.drop_duplicates(subset=["wijkcode"], keep='first')

print(metadata_national.shape)
metadata_national.head()
# Out:
# (900, 21)
#                ID                                              Title  \
# 0               0  Bevolking; geslacht, leeftijd, nationaliteit e...
# 1  DataProperties                                                NaN
# 2              ID                                           Position
# 3               0                                                  0
# 4               1                                                  1
#
#                           ShortTitle Identifier  \
# 0  Bevolking; nationaliteit en regio   84727NED
# 1                                NaN        NaN
# 2                           ParentID       Type
# 3                                NaN  Dimension
# 4                                NaN  Dimension
#
#                                              Summary            Modified  \
# 0  Bevolking naar geslacht, vijfjaarsleeftijdgroe...  2022-06-03 2:00:00
# 1                                                NaN                 NaN
# 2                                                Key               Title
# 3                                           Geslacht            Geslacht
# 4                                           Leeftijd            Leeftijd
#
#                                       ReasonDelivery ExplanatoryText  \
# 0                                      Actualisering             NaN
# 1                                                NaN             NaN
# 2                                        Description   ReleasePolicy
# 3                                                NaN             NaN
# 4  Het aantal gehele jaren dat op 1 januari van h...             NaN
#
#    Language Catalog  ...       Period  \
# 0        nl     CBS  ...  1995 - 2022
# 1       NaN     NaN  ...          NaN
# 2  Datatype    Unit  ...      Default
# 3       NaN     NaN  ...          NaN
# 4       NaN     NaN  ...          NaN
#
#                                     ShortDescription  \
# 0  \nDeze tabel bevat gegevens over de inwoners v...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Description  \
# 0  INHOUDSOPGAVE\n\n1. Toelichting\n2. Definities...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                  DefaultPresentation  \
# 0  ts=1653392806095&graphtype=Table&r=RegioS,Nati...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                     DefaultSelection          GraphTypes  \
# 0  $filter=((Leeftijd eq '10000')) and ((National...  Table,Bar,Line,Map
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#   OutputStatus Source    MetaDataModified SearchPriority
# 0     Regulier   CBS.  2022-06-03 2:00:00            2.0
# 1          NaN    NaN                 NaN            NaN
# 2          NaN    NaN                 NaN            NaN
# 3          NaN    NaN                 NaN            NaN
# 4          NaN    NaN                 NaN            NaN
#
# [5 rows x 21 columns]

# %%
def get_nationaliteit(row):
    data_row = metadata_national[metadata_national['ID'] == row['NationaliteitId']]
    value = "" if data_row.empty else data_row['Title'].iloc[0]
    return value
    

data_national = data_national.copy()

data_national['Nationaliteit'] = data_national.apply(lambda row: get_nationaliteit(row), axis=1)

print(data_national.shape)
data_national.head()
# Out:
# (45, 8)
#       ID Geslacht  Leeftijd NationaliteitId  RegioS  Perioden  Bevolking_1  \
# 0   2350  T001038     10000         T001059  GM0363  2021JJ00       873338
# 1  24302  T001038     10000         NAT9489  GM0363  2021JJ00       162462
# 2  46254  T001038     10000         NAT9267  GM0363  2021JJ00       710876
# 3  68206  T001038     10000         NAT9269  GM0363  2021JJ00        16905
# 4  90158  T001038     10000         NAT9270  GM0363  2021JJ00        15636
#
#                            Nationaliteit
# 0                                 Totaal
# 1  Totaal niet-Nederlandse nationaliteit
# 2                             Nederlands
# 3                                 Afrika
# 4                                Amerika

# %%
data_national = data_national[['NationaliteitId','Nationaliteit', 'Bevolking_1']]
data_national.to_csv(r'amsterdamers_nationaliteit.csv', index = False)
